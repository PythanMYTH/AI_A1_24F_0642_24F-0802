# %%
from algorithms.dls import dls

def iddfs(draw, grid, start, target, max_depth):

    for depth in range(max_depth):
        found = dls(draw, grid, start, target, depth)

        if found:
            return True

    return False
