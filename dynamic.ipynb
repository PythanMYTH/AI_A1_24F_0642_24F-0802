# %%
import random

def spawn_dynamic_wall(grid, probability):

    if random.random() < probability:

        empty_cells = [
            cell for row in grid for cell in row
            if not cell.is_wall()
        ]

        if empty_cells:
            random.choice(empty_cells).make_wall()
